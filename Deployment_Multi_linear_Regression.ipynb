# %%
import pickle

# %%
load_model=pickle.load(open("finalized_model_Mul_linear.sav",'rb'))
result=load_model.predict([[1834,745,3565,0,1]])
# Out:
# C:\Users\jency\.conda\envs\notebook-env\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[44292.13606348]])
